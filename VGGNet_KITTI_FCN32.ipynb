# %%
# --------------------------
# Source and reference
#   https://github.com/udacity/CarND-Semantic-Segmentation
#   https://gist.github.com/lianyi/a5ba8d84f5b68401c2313b05e020b062
#   https://medium.com/nanonets/how-to-do-image-segmentation-using-deep-learning-c673cc5862ef
# --------------------------

import tensorflow as tf
import warnings
import helper

# --------------------------
# USER-SPECIFIED DATA
# --------------------------

# Tune these parameters

NUMBER_OF_CLASSES = 2
IMAGE_SHAPE = (352, 1216)
EPOCHS = 50
BATCH_SIZE = 1
DROPOUT = 0.75
VALIDATION_SIZE = 45
MOMENTUM = 0.99

print_once = True

# Specify these directory paths

data_dir = './data'
runs_dir = './runs'
training_dir = './data/data_road/training'
testing_dir = './data/data_road/testing'
vgg_path = './data/vgg'

# --------------------------
# Check for a GPU
# --------------------------

#
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))

# --------------------------
# PLACEHOLDER TENSORS & SESSION
# --------------------------

correct_label = tf.placeholder(tf.float32, [None, IMAGE_SHAPE[0], IMAGE_SHAPE[1], NUMBER_OF_CLASSES])
learning_rate = tf.placeholder(tf.float32)
keep_prob = tf.placeholder(tf.float32)
global_session = None

# --------------------------
# HELPER FUNCTIONS
# --------------------------

import re
import random
import numpy as np
import os.path
import scipy.misc
import imageio
import shutil
import zipfile
import time
import datetime
import tensorflow as tf
from glob import glob
from urllib.request import urlretrieve
from tqdm import tqdm
import matplotlib.pyplot as plt
       
def create_batches(images_dir="", fg_color = [255, 255, 255], batch_size=1, check_once = True, check_always=False):
    batch_of_images = []
    batch_of_labels = []
    batch_of_image_file_paths = []
    if images_dir == "":
        print("Image directory not specified!")
        return np.array(batch_of_images), np.array(batch_of_labels)
    
    image_paths = glob(os.path.join(images_dir, 'image', '*.png'))
    label_paths = {
        re.sub(r'_road_', '_', os.path.basename(path)): path
        for path in glob(os.path.join(images_dir, 'gt_image', '*_road_*.png'))}
    
    if len(label_paths) == 0:
        print("Labels directory is empty!")
        return np.array(batch_of_images), np.array(batch_of_labels)
    
    image_file_count = 0
    random.shuffle(image_paths)
    for batch_i in range(0, len(image_paths), batch_size):
    #for batch_i in range(0, 10, batch_size):
        if batch_size > 1: print("Processing batch #", batch_i)
        images = []
        labels = []
        image_file_paths = []
        for image_file in image_paths[batch_i:batch_i+batch_size]:
            print("\tProcessing image #", image_file_count)
            # append image file name in array
            image_file_paths.append(os.path.basename(image_file))
            # get gt file corresponding to image file
            gt_image_file = label_paths[os.path.basename(image_file)]
            # read image file
            image = scipy.misc.imread(image_file)
            images.append(image)
            # read gt file create labels comprising of gt and bg
            gt_image = scipy.misc.imread(gt_image_file)
            gt_fg = np.all(gt_image == fg_color, axis=2)
            gt_fg = gt_fg.reshape(*gt_fg.shape, 1)
            label = np.concatenate((gt_fg, np.invert(gt_fg)), axis=2)
            labels.append(label)
            # for checking only
            if check_once or check_always:
                print("\tImage shape   :", image.shape)
                print("\tGT image shape:", gt_image.shape)
                print("\tLabel shape   :", label.shape)
                # check colors in GT image
                label_colors = {}
                for x in range(gt_image.shape[0]):
                    for y in range(gt_image.shape[1]):
                        color = gt_image[x, y]
                        color_string = "(" + str(color[0]) + ", " + str(color[1]) + ", " + str(color[2]) + ")"
                        if color_string not in label_colors:
                            label_colors[color_string] = 1
                        else:
                            label_colors[color_string] += 1
                print("\tLabel colors :")
                count = 1
                for key in label_colors.keys():
                    print("\t  Color #", count, ": ", key, "occurs", label_colors[key], "times")
                    count += 1
                # check count of gt and bg pixels
                print("\tFG sum        :", np.sum(label[:, :, 0]))
                print("\tBG sum        :", np.sum(label[:, :, 1]))
                print("\tGT sum        :", np.sum(label), "\n")
                check_once = False
            image_file_count += 1
            # add to batch
            batch_of_images.append(images)
            batch_of_labels.append(labels)
            batch_of_image_file_paths.append(image_file_paths)
    print("Total files processed:", image_file_count)
    # convert labels to numpy array
    return np.array(batch_of_images), np.array(batch_of_labels), batch_of_image_file_paths

def load_vgg(sess, vgg_path):
    # load the model and weights
    model = tf.saved_model.loader.load(sess, ['vgg16'], vgg_path)

    # Get Tensors to be returned from graph
    graph = tf.get_default_graph()
    image_input_layer = graph.get_tensor_by_name('image_input:0')
    keep_prob = graph.get_tensor_by_name('keep_prob:0')
    layer3 = graph.get_tensor_by_name('layer3_out:0')
    layer4 = graph.get_tensor_by_name('layer4_out:0')
    layer7 = graph.get_tensor_by_name('layer7_out:0')

    return image_input_layer, keep_prob, layer3, layer4, layer7, graph

def show_progress(current_iteration, total_iterations, operation_name=""):
    if total_iterations > 1:
        progress = int(100 * (current_iteration % total_iterations) / (total_iterations - 1))
        status = operation_name + " " + str(current_iteration + 1) + " " + "." * progress + " " + str(progress) + "%"
        print (status, end="\r")

# --------------------------
# MODEL FUNCTIONS
# --------------------------

def layers(vgg_layer3_out, vgg_layer4_out, vgg_layer7_out, NUMBER_OF_CLASSES):
    # Use a shorter variable name for simplicity
    layer3, layer4, layer7 = vgg_layer3_out, vgg_layer4_out, vgg_layer7_out

    # Apply 1x1 convolution in place of fully connected layer
    fcn8 = tf.layers.conv2d(layer7, filters=NUMBER_OF_CLASSES, kernel_size=1, name="fcn8")

    # Upsample fcn8 with size depth=(4096?) to match size of layer 4 so that we can add skip connection with 4th layer
    fcn9 = tf.layers.conv2d_transpose(fcn8, filters=layer4.get_shape().as_list()[-1],
                                      kernel_size=4, strides=(2, 2), padding='SAME', name="fcn9")

    # Add a skip connection between current final layer fcn8 and 4th layer
    #fcn9_skip_connected = tf.add(fcn9, layer4, name="fcn9_plus_vgg_layer4")

    # Upsample again
    #fcn10 = tf.layers.conv2d_transpose(fcn9_skip_connected, filters=layer3.get_shape().as_list()[-1],
    #                                   kernel_size=4, strides=(2, 2), padding='SAME', name="fcn10_conv2d")

    # Add skip connection
    #fcn10_skip_connected = tf.add(fcn10, layer3, name="fcn10_plus_vgg_layer3")

    # Upsample again
    #fcn11 = tf.layers.conv2d_transpose(fcn10_skip_connected, filters=NUMBER_OF_CLASSES,
    #                                   kernel_size=16, strides=(8, 8), padding='SAME', name="fcn11")

    #return fcn11
    return fcn9

def optimize(nn_last_layer, correct_label, learning_rate, NUMBER_OF_CLASSES, graph):
    
    # Reshape 4D tensors to 2D, each row represents a pixel, each column a class
    logits = tf.reshape(nn_last_layer, (-1, NUMBER_OF_CLASSES), name="fcn_logits")
    correct_label_reshaped = tf.reshape(correct_label, (-1, NUMBER_OF_CLASSES))

    # Calculate distance from actual labels using cross entropy
    with graph.as_default():
        #cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=correct_label_reshaped[:])
        cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=correct_label_reshaped[:])
    # Take mean for total loss
    loss_op = tf.reduce_mean(cross_entropy, name="fcn_loss")

    # The model implements this operation to find the weights/parameters that would yield correct pixel labels
    #train_op = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss_op, name="fcn_train_op")
    train_op = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=MOMENTUM).minimize(loss_op, name="fcn_train_op")

    return logits, train_op, loss_op

def train_nn(sess, epochs, batch_size, learning_rate, image_shape,
             training_images, training_labels, validation_images, validation_labels,
             logits, train_op, cross_entropy_loss,
             image_input_layer, correct_label, keep_prob):
    keep_prob_value = 0.5
    learning_rate_value = 0.001
    num_of_batches = len(training_images)
    num_of_validation_images = len(validation_images)
    
    start_time = datetime.datetime.now()
    print("\nStart time          : ", start_time)
    # create variables for stats
    epoch_start_time = start_time
    sum_of_epoch_times = 0.0
    
    # for plotting graphs
    collection_of_average_IoU_per_epoch = []
    collection_of_train_loss_per_epoch = []
    collection_of_average_validation_IoU_per_epoch = []
    collection_of_validation_loss_per_epoch = []
    
    for current_epoch in range(epochs):
        print("")                           
        print("=================================================")
        print("Epoch #", (current_epoch + 1), "in progress")
        print("Epoch start time    : ", epoch_start_time)
        train_loss = 0
        validation_loss = 0
        average_IoU_epoch = 0
        average_validation_IoU_epoch = 0
        
        # training loop
        for i in range(num_of_batches):   
            # run session to get predictions
            im_softmax, _, loss = sess.run([tf.nn.softmax(logits), train_op, cross_entropy_loss],
                               feed_dict={
                                   image_input_layer: training_images[i],
                                   correct_label: training_labels[i],
                                   keep_prob: keep_prob_value,
                                   learning_rate: learning_rate_value})
            train_loss += loss
            # show progress bar
            show_progress(
                current_iteration=i,
                total_iterations=num_of_batches,
                operation_name="training  ")
            # foreground is at index 0 of softmax
            im_softmax = im_softmax[:, 0].reshape(image_shape[0], image_shape[1])
            segmentation = (im_softmax > 0.5)
            segmentation = segmentation.reshape(image_shape[0], image_shape[1], 1)
            # calculate IoU
            only_segmentation = np.sum(segmentation)
            gt = training_labels[i][0][:, :, 0]
            only_gt = np.sum(gt)
            intersection = segmentation.astype(int).ravel().dot(gt.astype(int).ravel())
            union = only_segmentation + only_gt - intersection
            IoU = round(100.0 * intersection / union, 2)
            average_IoU_epoch += IoU
            # add to collections
            collection_of_average_IoU_per_epoch.append(IoU)
            collection_of_train_loss_per_epoch.append(loss)
        
        print("")
        # validation loop
        for i in range (num_of_validation_images):
            # read image, ground truth and filename
            image = validation_images[i][0]
            gt = validation_labels[i][0][:, :, 0]
            
            # run session to get predictions
            im_softmax, _, loss = sess.run([tf.nn.softmax(logits), train_op, cross_entropy_loss],
                                           feed_dict={
                                               image_input_layer: validation_images[i],
                                               correct_label: validation_labels[i],
                                               keep_prob: 1.0,
                                               learning_rate: learning_rate_value})
            validation_loss += loss
            show_progress(
                current_iteration=i,
                total_iterations=num_of_validation_images,
                operation_name="validation")
            # foreground is at index 0 of softmax
            im_softmax = im_softmax[:, 0].reshape(image_shape[0], image_shape[1])
            segmentation = (im_softmax > 0.5)
            segmentation = segmentation.reshape(image_shape[0], image_shape[1], 1)
            # calculate IoU
            only_segmentation = np.sum(segmentation)
            only_gt = np.sum(gt)
            intersection = segmentation.astype(int).ravel().dot(gt.astype(int).ravel())
            union = only_segmentation + only_gt - intersection
            IoU = round(100.0 * intersection / union, 2)
            average_validation_IoU_epoch += IoU
            # add to collections
            collection_of_average_validation_IoU_per_epoch.append(IoU)
            collection_of_validation_loss_per_epoch.append(loss)
        
        # stats for current epoch
        train_loss = round(train_loss, 2)
        validation_loss = round(validation_loss, 2)
        average_IoU_epoch = round(average_IoU_epoch/num_of_batches, 2)
        average_validation_IoU_epoch = round(average_IoU_epoch/num_of_validation_images, 2)
        epoch_stop_time = datetime.datetime.now()
        epoch_time = round((epoch_stop_time - epoch_start_time).total_seconds(), 2)
        sum_of_epoch_times = sum_of_epoch_times + epoch_time
        avg_iter_time = round(epoch_time * 1000 / num_of_batches, 2)
        epoch_start_time = epoch_stop_time
        # add to collections
        #collection_of_average_IoU_per_epoch.append(average_IoU_epoch)
        #collection_of_train_loss_per_epoch.append(train_loss)
        #collection_of_average_validation_IoU_per_epoch.append(average_validation_IoU_epoch)
        #collection_of_validation_loss_per_epoch.append(validation_loss)
        # display stats
        print("")
        print("Epoch stop time       : ", epoch_stop_time)
        print("Epochs completed      : ", current_epoch+1)
        print("Epoch time            : ", epoch_time, " seconds")
        print("Avg. iteration time   : ", avg_iter_time, " ms")
        print("Train loss            : ", train_loss)
        print("Average train IoU     : ", average_IoU_epoch, " %")
        print("Validation loss       : ", validation_loss)
        print("Average validation IoU: ", average_validation_IoU_epoch, " %")
        print("=================================================")
    training_output = []
    training_output.append(collection_of_average_IoU_per_epoch)
    training_output.append(collection_of_train_loss_per_epoch)
    training_output.append(collection_of_average_validation_IoU_per_epoch)
    training_output.append(collection_of_validation_loss_per_epoch)
    return training_output 

# --------------------------
# MAIN
# --------------------------
#if __name__ == '__main__':

# Download pretrained vgg model
helper.maybe_download_pretrained_vgg(data_dir)

# create batches from dataset
batch_size = 1
fg_color = np.array([255, 0, 255])
print("\nCreating training batch   ...")
training_images, training_labels, _ = create_batches(
    images_dir = training_dir,
    fg_color = fg_color,
    batch_size = batch_size,
    check_always = False)
print("\nCreating testing batch    ...")
testing_images, testing_labels, testing_image_file_paths = create_batches(
    images_dir = testing_dir,
    fg_color = fg_color,
    batch_size = batch_size,
    check_always = False)
print("\nCreating validation batch ...")
validation_images, training_images = np.split(training_images, [VALIDATION_SIZE])
validation_labels, training_labels = np.split(training_labels, [VALIDATION_SIZE])

print("")
print("Training batch of images created  :", training_images.shape)
print("Training batch of labels created  :", training_labels.shape)
print("")
print("Validation batch of images created:", validation_images.shape)
print("Validation batch of labels created:", validation_labels.shape)
print("")
print("Testing batch of images created   :", testing_images.shape)
print("Testing batch of labels created   :", testing_labels.shape)
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Default GPU Device: /device:GPU:0
#
# Creating training batch   ...
# 	Processing image # 0
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:107: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:110: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# 	Image shape   : (352, 1216, 3)
# 	GT image shape: (352, 1216, 3)
# 	Label shape   : (352, 1216, 2)
# 	Label colors :
# 	  Color # 1 :  (255, 0, 0) occurs 377595 times
# 	  Color # 2 :  (255, 0, 255) occurs 50437 times
# 	FG sum        : 50437
# 	BG sum        : 377595
# 	GT sum        : 428032
#
# 	Processing image # 1
# 	Processing image # 2
# 	Processing image # 3
# 	Processing image # 4
# 	Processing image # 5
# 	Processing image # 6
# 	Processing image # 7
# 	Processing image # 8
# 	Processing image # 9
# 	Processing image # 10
# 	Processing image # 11
# 	Processing image # 12
# 	Processing image # 13
# 	Processing image # 14
# 	Processing image # 15
# 	Processing image # 16
# 	Processing image # 17
# 	Processing image # 18
# 	Processing image # 19
# 	Processing image # 20
# 	Processing image # 21
# 	Processing image # 22
# 	Processing image # 23
# 	Processing image # 24
# 	Processing image # 25
# 	Processing image # 26
# 	Processing image # 27
# 	Processing image # 28
# 	Processing image # 29
# 	Processing image # 30
# 	Processing image # 31
# 	Processing image # 32
# 	Processing image # 33
# 	Processing image # 34
# 	Processing image # 35
# 	Processing image # 36
# 	Processing image # 37
# 	Processing image # 38
# 	Processing image # 39
# 	Processing image # 40
# 	Processing image # 41
# 	Processing image # 42
# 	Processing image # 43
# 	Processing image # 44
# 	Processing image # 45
# 	Processing image # 46
# 	Processing image # 47
# 	Processing image # 48
# 	Processing image # 49
# 	Processing image # 50
# 	Processing image # 51
# 	Processing image # 52
# 	Processing image # 53
# 	Processing image # 54
# 	Processing image # 55
# 	Processing image # 56
# 	Processing image # 57
# 	Processing image # 58
# 	Processing image # 59
# 	Processing image # 60
# 	Processing image # 61
# 	Processing image # 62
# 	Processing image # 63
# 	Processing image # 64
# 	Processing image # 65
# 	Processing image # 66
# 	Processing image # 67
# 	Processing image # 68
# 	Processing image # 69
# 	Processing image # 70
# 	Processing image # 71
# 	Processing image # 72
# 	Processing image # 73
# 	Processing image # 74
# 	Processing image # 75
# 	Processing image # 76
# 	Processing image # 77
# 	Processing image # 78
# 	Processing image # 79
# 	Processing image # 80
# 	Processing image # 81
# 	Processing image # 82
# 	Processing image # 83
# 	Processing image # 84
# 	Processing image # 85
# 	Processing image # 86
# 	Processing image # 87
# 	Processing image # 88
# 	Processing image # 89
# 	Processing image # 90
# 	Processing image # 91
# 	Processing image # 92
# 	Processing image # 93
# 	Processing image # 94
# 	Processing image # 95
# 	Processing image # 96
# 	Processing image # 97
# 	Processing image # 98
# 	Processing image # 99
# 	Processing image # 100
# 	Processing image # 101
# 	Processing image # 102
# 	Processing image # 103
# 	Processing image # 104
# 	Processing image # 105
# 	Processing image # 106
# 	Processing image # 107
# 	Processing image # 108
# 	Processing image # 109
# 	Processing image # 110
# 	Processing image # 111
# 	Processing image # 112
# 	Processing image # 113
# 	Processing image # 114
# 	Processing image # 115
# 	Processing image # 116
# 	Processing image # 117
# 	Processing image # 118
# 	Processing image # 119
# 	Processing image # 120
# 	Processing image # 121
# 	Processing image # 122
# 	Processing image # 123
# 	Processing image # 124
# 	Processing image # 125
# 	Processing image # 126
# 	Processing image # 127
# 	Processing image # 128
# 	Processing image # 129
# 	Processing image # 130
# 	Processing image # 131
# 	Processing image # 132
# 	Processing image # 133
# 	Processing image # 134
# 	Processing image # 135
# 	Processing image # 136
# 	Processing image # 137
# 	Processing image # 138
# 	Processing image # 139
# 	Processing image # 140
# 	Processing image # 141
# 	Processing image # 142
# 	Processing image # 143
# 	Processing image # 144
# 	Processing image # 145
# 	Processing image # 146
# 	Processing image # 147
# 	Processing image # 148
# 	Processing image # 149
# 	Processing image # 150
# 	Processing image # 151
# 	Processing image # 152
# 	Processing image # 153
# 	Processing image # 154
# 	Processing image # 155
# 	Processing image # 156
# 	Processing image # 157
# 	Processing image # 158
# 	Processing image # 159
# 	Processing image # 160
# 	Processing image # 161
# 	Processing image # 162
# 	Processing image # 163
# 	Processing image # 164
# 	Processing image # 165
# 	Processing image # 166
# 	Processing image # 167
# 	Processing image # 168
# 	Processing image # 169
# 	Processing image # 170
# 	Processing image # 171
# 	Processing image # 172
# 	Processing image # 173
# 	Processing image # 174
# 	Processing image # 175
# 	Processing image # 176
# 	Processing image # 177
# 	Processing image # 178
# 	Processing image # 179
# 	Processing image # 180
# 	Processing image # 181
# 	Processing image # 182
# 	Processing image # 183
# 	Processing image # 184
# 	Processing image # 185
# 	Processing image # 186
# 	Processing image # 187
# 	Processing image # 188
# 	Processing image # 189
# 	Processing image # 190
# 	Processing image # 191
# 	Processing image # 192
# 	Processing image # 193
# 	Processing image # 194
# 	Processing image # 195
# 	Processing image # 196
# 	Processing image # 197
# 	Processing image # 198
# 	Processing image # 199
# 	Processing image # 200
# 	Processing image # 201
# 	Processing image # 202
# 	Processing image # 203
# 	Processing image # 204
# 	Processing image # 205
# 	Processing image # 206
# 	Processing image # 207
# 	Processing image # 208
# 	Processing image # 209
# 	Processing image # 210
# 	Processing image # 211
# 	Processing image # 212
# 	Processing image # 213
# 	Processing image # 214
# 	Processing image # 215
# 	Processing image # 216
# 	Processing image # 217
# 	Processing image # 218
# 	Processing image # 219
# 	Processing image # 220
# 	Processing image # 221
# 	Processing image # 222
# 	Processing image # 223
# 	Processing image # 224
# 	Processing image # 225
# 	Processing image # 226
# 	Processing image # 227
# 	Processing image # 228
# 	Processing image # 229
# 	Processing image # 230
# 	Processing image # 231
# 	Processing image # 232
# 	Processing image # 233
# 	Processing image # 234
# 	Processing image # 235
# 	Processing image # 236
# 	Processing image # 237
# 	Processing image # 238
# 	Processing image # 239
# 	Processing image # 240
# 	Processing image # 241
# 	Processing image # 242
# 	Processing image # 243
# Total files processed: 244
#
# Creating testing batch    ...
# 	Processing image # 0
# 	Image shape   : (352, 1216, 3)
# 	GT image shape: (352, 1216, 3)
# 	Label shape   : (352, 1216, 2)
# 	Label colors :
# 	  Color # 1 :  (255, 0, 0) occurs 369822 times
# 	  Color # 2 :  (255, 0, 255) occurs 58210 times
# 	FG sum        : 58210
# 	BG sum        : 369822
# 	GT sum        : 428032
#
# 	Processing image # 1
# 	Processing image # 2
# 	Processing image # 3
# 	Processing image # 4
# 	Processing image # 5
# 	Processing image # 6
# 	Processing image # 7
# 	Processing image # 8
# 	Processing image # 9
# 	Processing image # 10
# 	Processing image # 11
# 	Processing image # 12
# 	Processing image # 13
# 	Processing image # 14
# 	Processing image # 15
# 	Processing image # 16
# 	Processing image # 17
# 	Processing image # 18
# 	Processing image # 19
# 	Processing image # 20
# 	Processing image # 21
# 	Processing image # 22
# 	Processing image # 23
# 	Processing image # 24
# 	Processing image # 25
# 	Processing image # 26
# 	Processing image # 27
# 	Processing image # 28
# 	Processing image # 29
# 	Processing image # 30
# 	Processing image # 31
# 	Processing image # 32
# 	Processing image # 33
# 	Processing image # 34
# 	Processing image # 35
# 	Processing image # 36
# 	Processing image # 37
# 	Processing image # 38
# 	Processing image # 39
# 	Processing image # 40
# 	Processing image # 41
# 	Processing image # 42
# 	Processing image # 43
# 	Processing image # 44
# Total files processed: 45
#
# Creating validation batch ...
#
# Training batch of images created  : (199, 1, 352, 1216, 3)
# Training batch of labels created  : (199, 1, 352, 1216, 2)
#
# Validation batch of images created: (45, 1, 352, 1216, 3)
# Validation batch of labels created: (45, 1, 352, 1216, 2)
#
# Testing batch of images created   : (45, 1, 352, 1216, 3)
# Testing batch of labels created   : (45, 1, 352, 1216, 2)

# %%
global_session = tf.Session()
#with tf.Session() as session:

# Returns the three layers, keep probability and input layer from the vgg architecture
image_input_layer, keep_prob, layer3, layer4, layer7, graph = load_vgg(global_session, vgg_path)

# The resulting network architecture from adding a decoder on top of the given vgg model
model_output = layers(layer3, layer4, layer7, NUMBER_OF_CLASSES)

# Returns the output logits, training operation and cost operation to be used
# - logits: each row represents a pixel, each column a class
# - train_op: function used to get the right parameters to the model to correctly label the pixels
# - cross_entropy_loss: function outputting the cost which we are minimizing, lower cost should yield higher accuracy
logits, train_op, cross_entropy_loss = optimize(model_output, correct_label, learning_rate, NUMBER_OF_CLASSES, graph)

# Initialize all variables
#session.run(tf.global_variables_initializer())
#session.run(tf.local_variables_initializer())
global_session.run(tf.global_variables_initializer())
global_session.run(tf.local_variables_initializer())

print("Model build successful, starting training")

# Train the neural network
train_output = train_nn(global_session, EPOCHS, BATCH_SIZE, learning_rate, IMAGE_SHAPE,
         training_images, training_labels, validation_images, validation_labels,
         logits, train_op, cross_entropy_loss,
         image_input_layer, correct_label, keep_prob)
print("\nTraining Finished!")
# Out:
# INFO:tensorflow:Restoring parameters from ./data/vgg/variables/variables
# Model build successful, starting training
#
# Start time          :  2018-11-28 06:52:03.057639
#
# =================================================
# Epoch # 1 in progress
# Epoch start time    :  2018-11-28 06:52:03.057639
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 06:59:41.982288
# Epochs completed      :  1
# Epoch time            :  458.92  seconds
# Avg. iteration time   :  2306.13  ms
# Train loss            :  110.43
# Average train IoU     :  9.63  %
# Validation loss       :  12.81
# Average validation IoU:  0.21  %
# =================================================
#
# =================================================
# Epoch # 2 in progress
# Epoch start time    :  2018-11-28 06:59:41.982288
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:07:09.710558
# Epochs completed      :  2
# Epoch time            :  447.73  seconds
# Avg. iteration time   :  2249.9  ms
# Train loss            :  56.4
# Average train IoU     :  19.37  %
# Validation loss       :  12.57
# Average validation IoU:  0.43  %
# =================================================
#
# =================================================
# Epoch # 3 in progress
# Epoch start time    :  2018-11-28 07:07:09.710558
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:14:37.643233
# Epochs completed      :  3
# Epoch time            :  447.93  seconds
# Avg. iteration time   :  2250.9  ms
# Train loss            :  54.39
# Average train IoU     :  20.63  %
# Validation loss       :  12.23
# Average validation IoU:  0.46  %
# =================================================
#
# =================================================
# Epoch # 4 in progress
# Epoch start time    :  2018-11-28 07:14:37.643233
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:22:06.689512
# Epochs completed      :  4
# Epoch time            :  449.05  seconds
# Avg. iteration time   :  2256.53  ms
# Train loss            :  52.71
# Average train IoU     :  23.36  %
# Validation loss       :  11.84
# Average validation IoU:  0.52  %
# =================================================
#
# =================================================
# Epoch # 5 in progress
# Epoch start time    :  2018-11-28 07:22:06.689512
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:29:37.772358
# Epochs completed      :  5
# Epoch time            :  451.08  seconds
# Avg. iteration time   :  2266.73  ms
# Train loss            :  51.74
# Average train IoU     :  24.31  %
# Validation loss       :  11.55
# Average validation IoU:  0.54  %
# =================================================
#
# =================================================
# Epoch # 6 in progress
# Epoch start time    :  2018-11-28 07:29:37.772358
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:37:10.008174
# Epochs completed      :  6
# Epoch time            :  452.24  seconds
# Avg. iteration time   :  2272.56  ms
# Train loss            :  49.58
# Average train IoU     :  29.05  %
# Validation loss       :  10.81
# Average validation IoU:  0.65  %
# =================================================
#
# =================================================
# Epoch # 7 in progress
# Epoch start time    :  2018-11-28 07:37:10.008174
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:44:43.184773
# Epochs completed      :  7
# Epoch time            :  453.18  seconds
# Avg. iteration time   :  2277.29  ms
# Train loss            :  46.28
# Average train IoU     :  34.2  %
# Validation loss       :  10.26
# Average validation IoU:  0.76  %
# =================================================
#
# =================================================
# Epoch # 8 in progress
# Epoch start time    :  2018-11-28 07:44:43.184773
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:52:18.007244
# Epochs completed      :  8
# Epoch time            :  454.82  seconds
# Avg. iteration time   :  2285.53  ms
# Train loss            :  45.34
# Average train IoU     :  34.89  %
# Validation loss       :  10.17
# Average validation IoU:  0.78  %
# =================================================
#
# =================================================
# Epoch # 9 in progress
# Epoch start time    :  2018-11-28 07:52:18.007244
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 07:59:54.407199
# Epochs completed      :  9
# Epoch time            :  456.4  seconds
# Avg. iteration time   :  2293.47  ms
# Train loss            :  44.87
# Average train IoU     :  36.78  %
# Validation loss       :  9.95
# Average validation IoU:  0.82  %
# =================================================
#
# =================================================
# Epoch # 10 in progress
# Epoch start time    :  2018-11-28 07:59:54.407199
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 08:07:31.297603
# Epochs completed      :  10
# Epoch time            :  456.89  seconds
# Avg. iteration time   :  2295.93  ms
# Train loss            :  43.77
# Average train IoU     :  38.49  %
# Validation loss       :  9.74
# Average validation IoU:  0.86  %
# =================================================
#
# =================================================
# Epoch # 11 in progress
# Epoch start time    :  2018-11-28 08:07:31.297603
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 08:15:09.046100
# Epochs completed      :  11
# Epoch time            :  457.75  seconds
# Avg. iteration time   :  2300.25  ms
# Train loss            :  43.15
# Average train IoU     :  39.52  %
# Validation loss       :  9.69
# Average validation IoU:  0.88  %
# =================================================
#
# =================================================
# Epoch # 12 in progress
# Epoch start time    :  2018-11-28 08:15:09.046100
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 08:22:47.741774
# Epochs completed      :  12
# Epoch time            :  458.7  seconds
# Avg. iteration time   :  2305.03  ms
# Train loss            :  43.12
# Average train IoU     :  40.34  %
# Validation loss       :  9.44
# Average validation IoU:  0.9  %
# =================================================
#
# =================================================
# Epoch # 13 in progress
# Epoch start time    :  2018-11-28 08:22:47.741774
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 08:30:28.575911
# Epochs completed      :  13
# Epoch time            :  460.83  seconds
# Avg. iteration time   :  2315.73  ms
# Train loss            :  42.16
# Average train IoU     :  41.83  %
# Validation loss       :  9.13
# Average validation IoU:  0.93  %
# =================================================
#
# =================================================
# Epoch # 14 in progress
# Epoch start time    :  2018-11-28 08:30:28.575911
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 08:38:10.368072
# Epochs completed      :  14
# Epoch time            :  461.79  seconds
# Avg. iteration time   :  2320.55  ms
# Train loss            :  39.35
# Average train IoU     :  47.56  %
# Validation loss       :  8.66
# Average validation IoU:  1.06  %
# =================================================
#
# =================================================
# Epoch # 15 in progress
# Epoch start time    :  2018-11-28 08:38:10.368072
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 08:45:54.666702
# Epochs completed      :  15
# Epoch time            :  464.3  seconds
# Avg. iteration time   :  2333.17  ms
# Train loss            :  36.16
# Average train IoU     :  53.23  %
# Validation loss       :  7.82
# Average validation IoU:  1.18  %
# =================================================
#
# =================================================
# Epoch # 16 in progress
# Epoch start time    :  2018-11-28 08:45:54.666702
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 08:53:41.264176
# Epochs completed      :  16
# Epoch time            :  466.6  seconds
# Avg. iteration time   :  2344.72  ms
# Train loss            :  36.08
# Average train IoU     :  54.02  %
# Validation loss       :  7.72
# Average validation IoU:  1.2  %
# =================================================
#
# =================================================
# Epoch # 17 in progress
# Epoch start time    :  2018-11-28 08:53:41.264176
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:01:30.965241
# Epochs completed      :  17
# Epoch time            :  469.7  seconds
# Avg. iteration time   :  2360.3  ms
# Train loss            :  34.51
# Average train IoU     :  55.95  %
# Validation loss       :  6.97
# Average validation IoU:  1.24  %
# =================================================
#
# =================================================
# Epoch # 18 in progress
# Epoch start time    :  2018-11-28 09:01:30.965241
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:09:22.703932
# Epochs completed      :  18
# Epoch time            :  471.74  seconds
# Avg. iteration time   :  2370.55  ms
# Train loss            :  32.78
# Average train IoU     :  58.8  %
# Validation loss       :  6.81
# Average validation IoU:  1.31  %
# =================================================
#
# =================================================
# Epoch # 19 in progress
# Epoch start time    :  2018-11-28 09:09:22.703932
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:17:17.800461
# Epochs completed      :  19
# Epoch time            :  475.1  seconds
# Avg. iteration time   :  2387.44  ms
# Train loss            :  29.11
# Average train IoU     :  63.53  %
# Validation loss       :  5.67
# Average validation IoU:  1.41  %
# =================================================
#
# =================================================
# Epoch # 20 in progress
# Epoch start time    :  2018-11-28 09:17:17.800461
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:25:14.928146
# Epochs completed      :  20
# Epoch time            :  477.13  seconds
# Avg. iteration time   :  2397.64  ms
# Train loss            :  25.7
# Average train IoU     :  67.74  %
# Validation loss       :  5.36
# Average validation IoU:  1.51  %
# =================================================
#
# =================================================
# Epoch # 21 in progress
# Epoch start time    :  2018-11-28 09:25:14.928146
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:33:14.666185
# Epochs completed      :  21
# Epoch time            :  479.74  seconds
# Avg. iteration time   :  2410.75  ms
# Train loss            :  24.42
# Average train IoU     :  69.25  %
# Validation loss       :  5.14
# Average validation IoU:  1.54  %
# =================================================
#
# =================================================
# Epoch # 22 in progress
# Epoch start time    :  2018-11-28 09:33:14.666185
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:41:17.598847
# Epochs completed      :  22
# Epoch time            :  482.93  seconds
# Avg. iteration time   :  2426.78  ms
# Train loss            :  23.92
# Average train IoU     :  69.84  %
# Validation loss       :  4.61
# Average validation IoU:  1.55  %
# =================================================
#
# =================================================
# Epoch # 23 in progress
# Epoch start time    :  2018-11-28 09:41:17.598847
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:49:23.554752
# Epochs completed      :  23
# Epoch time            :  485.96  seconds
# Avg. iteration time   :  2442.01  ms
# Train loss            :  23.56
# Average train IoU     :  70.33  %
# Validation loss       :  4.74
# Average validation IoU:  1.56  %
# =================================================
#
# =================================================
# Epoch # 24 in progress
# Epoch start time    :  2018-11-28 09:49:23.554752
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 09:57:33.950341
# Epochs completed      :  24
# Epoch time            :  490.4  seconds
# Avg. iteration time   :  2464.32  ms
# Train loss            :  22.02
# Average train IoU     :  72.47  %
# Validation loss       :  4.41
# Average validation IoU:  1.61  %
# =================================================
#
# =================================================
# Epoch # 25 in progress
# Epoch start time    :  2018-11-28 09:57:33.950341
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 10:05:47.508483
# Epochs completed      :  25
# Epoch time            :  493.56  seconds
# Avg. iteration time   :  2480.2  ms
# Train loss            :  18.97
# Average train IoU     :  75.98  %
# Validation loss       :  3.63
# Average validation IoU:  1.69  %
# =================================================
#
# =================================================
# Epoch # 26 in progress
# Epoch start time    :  2018-11-28 10:05:47.508483
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 10:14:04.692529
# Epochs completed      :  26
# Epoch time            :  497.18  seconds
# Avg. iteration time   :  2498.39  ms
# Train loss            :  18.6
# Average train IoU     :  76.29  %
# Validation loss       :  3.88
# Average validation IoU:  1.7  %
# =================================================
#
# =================================================
# Epoch # 27 in progress
# Epoch start time    :  2018-11-28 10:14:04.692529
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 10:22:24.348658
# Epochs completed      :  27
# Epoch time            :  499.66  seconds
# Avg. iteration time   :  2510.85  ms
# Train loss            :  18.38
# Average train IoU     :  76.38  %
# Validation loss       :  3.94
# Average validation IoU:  1.7  %
# =================================================
#
# =================================================
# Epoch # 28 in progress
# Epoch start time    :  2018-11-28 10:22:24.348658
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 10:30:47.287425
# Epochs completed      :  28
# Epoch time            :  502.94  seconds
# Avg. iteration time   :  2527.34  ms
# Train loss            :  19.34
# Average train IoU     :  75.25  %
# Validation loss       :  3.74
# Average validation IoU:  1.67  %
# =================================================
#
# =================================================
# Epoch # 29 in progress
# Epoch start time    :  2018-11-28 10:30:47.287425
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 10:39:14.562619
# Epochs completed      :  29
# Epoch time            :  507.28  seconds
# Avg. iteration time   :  2549.15  ms
# Train loss            :  19.11
# Average train IoU     :  75.81  %
# Validation loss       :  4.22
# Average validation IoU:  1.68  %
# =================================================
#
# =================================================
# Epoch # 30 in progress
# Epoch start time    :  2018-11-28 10:39:14.562619
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 10:47:45.311436
# Epochs completed      :  30
# Epoch time            :  510.75  seconds
# Avg. iteration time   :  2566.58  ms
# Train loss            :  20.5
# Average train IoU     :  74.35  %
# Validation loss       :  3.67
# Average validation IoU:  1.65  %
# =================================================
#
# =================================================
# Epoch # 31 in progress
# Epoch start time    :  2018-11-28 10:47:45.311436
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 10:56:19.258135
# Epochs completed      :  31
# Epoch time            :  513.95  seconds
# Avg. iteration time   :  2582.66  ms
# Train loss            :  17.85
# Average train IoU     :  77.41  %
# Validation loss       :  3.34
# Average validation IoU:  1.72  %
# =================================================
#
# =================================================
# Epoch # 32 in progress
# Epoch start time    :  2018-11-28 10:56:19.258135
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 11:04:56.752680
# Epochs completed      :  32
# Epoch time            :  517.49  seconds
# Avg. iteration time   :  2600.45  ms
# Train loss            :  14.93
# Average train IoU     :  80.96  %
# Validation loss       :  2.78
# Average validation IoU:  1.8  %
# =================================================
#
# =================================================
# Epoch # 33 in progress
# Epoch start time    :  2018-11-28 11:04:56.752680
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 11:13:38.598307
# Epochs completed      :  33
# Epoch time            :  521.85  seconds
# Avg. iteration time   :  2622.36  ms
# Train loss            :  13.94
# Average train IoU     :  82.2  %
# Validation loss       :  2.91
# Average validation IoU:  1.83  %
# =================================================
#
# =================================================
# Epoch # 34 in progress
# Epoch start time    :  2018-11-28 11:13:38.598307
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 11:22:25.083148
# Epochs completed      :  34
# Epoch time            :  526.48  seconds
# Avg. iteration time   :  2645.63  ms
# Train loss            :  14.05
# Average train IoU     :  81.9  %
# Validation loss       :  2.91
# Average validation IoU:  1.82  %
# =================================================
#
# =================================================
# Epoch # 35 in progress
# Epoch start time    :  2018-11-28 11:22:25.083148
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 11:31:16.408076
# Epochs completed      :  35
# Epoch time            :  531.32  seconds
# Avg. iteration time   :  2669.95  ms
# Train loss            :  17.8
# Average train IoU     :  77.58  %
# Validation loss       :  2.87
# Average validation IoU:  1.72  %
# =================================================
#
# =================================================
# Epoch # 36 in progress
# Epoch start time    :  2018-11-28 11:31:16.408076
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 11:40:13.129594
# Epochs completed      :  36
# Epoch time            :  536.72  seconds
# Avg. iteration time   :  2697.09  ms
# Train loss            :  16.92
# Average train IoU     :  78.64  %
# Validation loss       :  3.23
# Average validation IoU:  1.75  %
# =================================================
#
# =================================================
# Epoch # 37 in progress
# Epoch start time    :  2018-11-28 11:40:13.129594
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 11:49:13.152091
# Epochs completed      :  37
# Epoch time            :  540.02  seconds
# Avg. iteration time   :  2713.67  ms
# Train loss            :  19.58
# Average train IoU     :  75.64  %
# Validation loss       :  4.4
# Average validation IoU:  1.68  %
# =================================================
#
# =================================================
# Epoch # 38 in progress
# Epoch start time    :  2018-11-28 11:49:13.152091
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 11:58:17.879743
# Epochs completed      :  38
# Epoch time            :  544.73  seconds
# Avg. iteration time   :  2737.34  ms
# Train loss            :  19.53
# Average train IoU     :  75.75  %
# Validation loss       :  3.75
# Average validation IoU:  1.68  %
# =================================================
#
# =================================================
# Epoch # 39 in progress
# Epoch start time    :  2018-11-28 11:58:17.879743
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 12:07:27.098654
# Epochs completed      :  39
# Epoch time            :  549.22  seconds
# Avg. iteration time   :  2759.9  ms
# Train loss            :  15.82
# Average train IoU     :  79.89  %
# Validation loss       :  2.84
# Average validation IoU:  1.78  %
# =================================================
#
# =================================================
# Epoch # 40 in progress
# Epoch start time    :  2018-11-28 12:07:27.098654
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 12:16:42.341226
# Epochs completed      :  40
# Epoch time            :  555.24  seconds
# Avg. iteration time   :  2790.15  ms
# Train loss            :  12.41
# Average train IoU     :  84.13  %
# Validation loss       :  2.46
# Average validation IoU:  1.87  %
# =================================================
#
# =================================================
# Epoch # 41 in progress
# Epoch start time    :  2018-11-28 12:16:42.341226
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 12:26:02.713552
# Epochs completed      :  41
# Epoch time            :  560.37  seconds
# Avg. iteration time   :  2815.93  ms
# Train loss            :  12.72
# Average train IoU     :  83.63  %
# Validation loss       :  2.46
# Average validation IoU:  1.86  %
# =================================================
#
# =================================================
# Epoch # 42 in progress
# Epoch start time    :  2018-11-28 12:26:02.713552
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 12:35:28.728075
# Epochs completed      :  42
# Epoch time            :  566.01  seconds
# Avg. iteration time   :  2844.27  ms
# Train loss            :  14.81
# Average train IoU     :  80.66  %
# Validation loss       :  3.3
# Average validation IoU:  1.79  %
# =================================================
#
# =================================================
# Epoch # 43 in progress
# Epoch start time    :  2018-11-28 12:35:28.728075
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 12:44:58.904930
# Epochs completed      :  43
# Epoch time            :  570.18  seconds
# Avg. iteration time   :  2865.23  ms
# Train loss            :  13.53
# Average train IoU     :  82.59  %
# Validation loss       :  2.53
# Average validation IoU:  1.84  %
# =================================================
#
# =================================================
# Epoch # 44 in progress
# Epoch start time    :  2018-11-28 12:44:58.904930
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 12:54:34.951677
# Epochs completed      :  44
# Epoch time            :  576.05  seconds
# Avg. iteration time   :  2894.72  ms
# Train loss            :  11.31
# Average train IoU     :  85.34  %
# Validation loss       :  2.31
# Average validation IoU:  1.9  %
# =================================================
#
# =================================================
# Epoch # 45 in progress
# Epoch start time    :  2018-11-28 12:54:34.951677
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 13:04:15.546847
# Epochs completed      :  45
# Epoch time            :  580.6  seconds
# Avg. iteration time   :  2917.59  ms
# Train loss            :  12.29
# Average train IoU     :  83.92  %
# Validation loss       :  2.34
# Average validation IoU:  1.86  %
# =================================================
#
# =================================================
# Epoch # 46 in progress
# Epoch start time    :  2018-11-28 13:04:15.546847
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 13:14:01.768540
# Epochs completed      :  46
# Epoch time            :  586.22  seconds
# Avg. iteration time   :  2945.83  ms
# Train loss            :  12.3
# Average train IoU     :  83.84  %
# Validation loss       :  2.35
# Average validation IoU:  1.86  %
# =================================================
#
# =================================================
# Epoch # 47 in progress
# Epoch start time    :  2018-11-28 13:14:01.768540
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 13:23:54.221546
# Epochs completed      :  47
# Epoch time            :  592.45  seconds
# Avg. iteration time   :  2977.14  ms
# Train loss            :  11.53
# Average train IoU     :  84.96  %
# Validation loss       :  2.24
# Average validation IoU:  1.89  %
# =================================================
#
# =================================================
# Epoch # 48 in progress
# Epoch start time    :  2018-11-28 13:23:54.221546
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 13:33:52.844863
# Epochs completed      :  48
# Epoch time            :  598.62  seconds
# Avg. iteration time   :  3008.14  ms
# Train loss            :  11.4
# Average train IoU     :  85.09  %
# Validation loss       :  2.91
# Average validation IoU:  1.89  %
# =================================================
#
# =================================================
# Epoch # 49 in progress
# Epoch start time    :  2018-11-28 13:33:52.844863
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 13:43:57.298430
# Epochs completed      :  49
# Epoch time            :  604.45  seconds
# Avg. iteration time   :  3037.44  ms
# Train loss            :  13.1
# Average train IoU     :  82.71  %
# Validation loss       :  2.33
# Average validation IoU:  1.84  %
# =================================================
#
# =================================================
# Epoch # 50 in progress
# Epoch start time    :  2018-11-28 13:43:57.298430
# training   199 .................................................................................................... 100%
# validation 45 .................................................................................................... 100%
# Epoch stop time       :  2018-11-28 13:54:09.273413
# Epochs completed      :  50
# Epoch time            :  611.97  seconds
# Avg. iteration time   :  3075.23  ms
# Train loss            :  13.5
# Average train IoU     :  82.31  %
# Validation loss       :  2.5
# Average validation IoU:  1.83  %
# =================================================
#
# Training Finished!

# %%
collection_of_average_IoU_per_epoch = train_output[0]
collection_of_train_loss_per_epoch = train_output[1]
collection_of_average_validation_IoU_per_epoch = train_output[2]
collection_of_validation_loss_per_epoch = train_output[3]

# plot training accuracy graph
plt.plot(collection_of_average_IoU_per_epoch) 
plt.plot(collection_of_average_validation_IoU_per_epoch) 
plt.xlabel("Epochs")
plt.ylabel("Average IoU (%)") 
plt.title("Training and Validation Accuracies (IoU)") 
plt.show()

# plot training accuracy graph
plt.plot(collection_of_train_loss_per_epoch)
plt.plot(collection_of_validation_loss_per_epoch)
plt.xlabel("Epochs")
plt.ylabel("Cross Entropy Loss") 
plt.title("Training adn Validation Losses") 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-149f404bf901> in <module>()
# ----> 1 collection_of_average_IoU_per_epoch = train_output[0]
#       2 collection_of_train_loss_per_epoch = train_output[1]
#       3 collection_of_average_validation_IoU_per_epoch = train_output[2]
#       4 collection_of_validation_loss_per_epoch = train_output[3]
#       5
#
# NameError: name 'train_output' is not defined

# %%
num_of_testing_images = 1
def save_inference_samples(sess, image_shape, runs_dir,
                           testing_images, testing_labels, testing_image_file_paths,
                           image_input_layer, logits, keep_prob):
    def gen_test_output(sess, image_shape,
                    testing_images, testing_labels, testing_image_file_paths,
                    logits, image_pl, keep_prob):
        """
        Generate test output using the test images
        :param sess: TF session
        :param logits: TF Tensor for the logits
        :param keep_prob: TF Placeholder for the dropout keep robability
        :param image_pl: TF Placeholder for the image placeholder
        :param image_shape: Tuple - Shape of image
        :return: Output for for each test image
        """
        num_of_testing_images = len(testing_images)
        for i in range (num_of_testing_images):
            # read image, ground truth and filename
            image = testing_images[i][0]
            gt = testing_labels[i][0][:, :, 0]
            image_file = testing_image_file_paths[i][0]

            #loss, _ = sess.run([cross_entropy_loss, train_op],
            #                   feed_dict={input_image: X_batch, correct_label: gt_batch,
            #                              keep_prob: keep_prob_value, learning_rate: learning_rate_value})
            #total_loss += loss

            # run session to get predictions
            im_softmax = sess.run(
                [tf.nn.softmax(logits)],
                {keep_prob: 1.0, image_pl: [image]})

            # foreground is at index 0 of softmax
            #im_softmax = im_softmax[0][:, 1].reshape(image_shape[0], image_shape[1])
            im_softmax = im_softmax[0][:, 0].reshape(image_shape[0], image_shape[1])
            segmentation = (im_softmax > 0.5)
            segmentation = segmentation.reshape(image_shape[0], image_shape[1], 1)

            only_segmentation = np.sum(segmentation)
            only_gt = np.sum(gt)
            intersection = segmentation.astype(int).ravel().dot(gt.astype(int).ravel())

            union = only_segmentation + only_gt - intersection
            IoU = round(100.0 * intersection / union, 2)

            print("")
            print("Test image #", i)
            print("\tintersection: ", intersection)
            print("\tonly seg    : ", only_segmentation)
            print("\tonly gt     : ", only_gt)
            print("\tunion       : ", union)
            print("\tIoU         : ", IoU, " %")

            mask = np.dot(segmentation, np.array([[0, 255, 0, 127]]))
            mask = scipy.misc.toimage(mask, mode="RGBA")
            result_image = scipy.misc.toimage(image)
            result_image.paste(mask, box=None, mask=mask)
            #yield os.path.basename(image_file), np.array(result_image)
            yield image_file, np.array(result_image), IoU
    
    # Make folder for current run
    output_dir = os.path.join(runs_dir, str(time.time()))
    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    os.makedirs(output_dir)

    # Run NN on test images and save them to HD
    print("Saving test images to: {}".format(output_dir))
    
    image_outputs = gen_test_output(
        sess, image_shape,
        testing_images, testing_labels, testing_image_file_paths,
        logits, image_input_layer, keep_prob)
    
    average_IoU = 0.0
    num_of_test_images = 0
    for name, image, IoU in image_outputs:
        scipy.misc.imsave(os.path.join(output_dir, name), image)
        average_IoU += IoU
        num_of_test_images += 1
    average_IoU = round(average_IoU/num_of_test_images, 2)
    return average_IoU

# Run the model with the test images and save each painted output image (roads painted green)
average_IoU = save_inference_samples(global_session, IMAGE_SHAPE, runs_dir,
                       testing_images, testing_labels, testing_image_file_paths,
                       image_input_layer, logits, keep_prob)
print("")
print("Average IoU: ", average_IoU, "%")
# Out:
# Saving test images to: ./runs/1543413250.5356727
#
# Test image # 0
# 	intersection:  27951
# 	only seg    :  64657
# 	only gt     :  58210
# 	union       :  94916
# 	IoU         :  29.45  %
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:56: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:57: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:79: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Test image # 1
# 	intersection:  62081
# 	only seg    :  92038
# 	only gt     :  69969
# 	union       :  99926
# 	IoU         :  62.13  %
#
# Test image # 2
# 	intersection:  60287
# 	only seg    :  80554
# 	only gt     :  96046
# 	union       :  116313
# 	IoU         :  51.83  %
#
# Test image # 3
# 	intersection:  33470
# 	only seg    :  63376
# 	only gt     :  58290
# 	union       :  88196
# 	IoU         :  37.95  %
#
# Test image # 4
# 	intersection:  46147
# 	only seg    :  95960
# 	only gt     :  54920
# 	union       :  104733
# 	IoU         :  44.06  %
#
# Test image # 5
# 	intersection:  44901
# 	only seg    :  99460
# 	only gt     :  52420
# 	union       :  106979
# 	IoU         :  41.97  %
#
# Test image # 6
# 	intersection:  56704
# 	only seg    :  82591
# 	only gt     :  91053
# 	union       :  116940
# 	IoU         :  48.49  %
#
# Test image # 7
# 	intersection:  36632
# 	only seg    :  66399
# 	only gt     :  77733
# 	union       :  107500
# 	IoU         :  34.08  %
#
# Test image # 8
# 	intersection:  43628
# 	only seg    :  77194
# 	only gt     :  61500
# 	union       :  95066
# 	IoU         :  45.89  %
#
# Test image # 9
# 	intersection:  48184
# 	only seg    :  93679
# 	only gt     :  83896
# 	union       :  129391
# 	IoU         :  37.24  %
#
# Test image # 10
# 	intersection:  39137
# 	only seg    :  61995
# 	only gt     :  55055
# 	union       :  77913
# 	IoU         :  50.23  %
#
# Test image # 11
# 	intersection:  62895
# 	only seg    :  101406
# 	only gt     :  86841
# 	union       :  125352
# 	IoU         :  50.17  %
#
# Test image # 12
# 	intersection:  63201
# 	only seg    :  100869
# 	only gt     :  86483
# 	union       :  124151
# 	IoU         :  50.91  %
#
# Test image # 13
# 	intersection:  40254
# 	only seg    :  88799
# 	only gt     :  56149
# 	union       :  104694
# 	IoU         :  38.45  %
#
# Test image # 14
# 	intersection:  41959
# 	only seg    :  81031
# 	only gt     :  58594
# 	union       :  97666
# 	IoU         :  42.96  %
#
# Test image # 15
# 	intersection:  45346
# 	only seg    :  98816
# 	only gt     :  56865
# 	union       :  110335
# 	IoU         :  41.1  %
#
# Test image # 16
# 	intersection:  42007
# 	only seg    :  77075
# 	only gt     :  60541
# 	union       :  95609
# 	IoU         :  43.94  %
#
# Test image # 17
# 	intersection:  57777
# 	only seg    :  97383
# 	only gt     :  74574
# 	union       :  114180
# 	IoU         :  50.6  %
#
# Test image # 18
# 	intersection:  36239
# 	only seg    :  93423
# 	only gt     :  49841
# 	union       :  107025
# 	IoU         :  33.86  %
#
# Test image # 19
# 	intersection:  75424
# 	only seg    :  107560
# 	only gt     :  109428
# 	union       :  141564
# 	IoU         :  53.28  %
#
# Test image # 20
# 	intersection:  59709
# 	only seg    :  98791
# 	only gt     :  83191
# 	union       :  122273
# 	IoU         :  48.83  %
#
# Test image # 21
# 	intersection:  36343
# 	only seg    :  80096
# 	only gt     :  58613
# 	union       :  102366
# 	IoU         :  35.5  %
#
# Test image # 22
# 	intersection:  36164
# 	only seg    :  78545
# 	only gt     :  55424
# 	union       :  97805
# 	IoU         :  36.98  %
#
# Test image # 23
# 	intersection:  64680
# 	only seg    :  88180
# 	only gt     :  103186
# 	union       :  126686
# 	IoU         :  51.06  %
#
# Test image # 24
# 	intersection:  41520
# 	only seg    :  78603
# 	only gt     :  62075
# 	union       :  99158
# 	IoU         :  41.87  %
#
# Test image # 25
# 	intersection:  69768
# 	only seg    :  94604
# 	only gt     :  101967
# 	union       :  126803
# 	IoU         :  55.02  %
#
# Test image # 26
# 	intersection:  27387
# 	only seg    :  65784
# 	only gt     :  56227
# 	union       :  94624
# 	IoU         :  28.94  %
#
# Test image # 27
# 	intersection:  54075
# 	only seg    :  70949
# 	only gt     :  82362
# 	union       :  99236
# 	IoU         :  54.49  %
#
# Test image # 28
# 	intersection:  69073
# 	only seg    :  104673
# 	only gt     :  87986
# 	union       :  123586
# 	IoU         :  55.89  %
#
# Test image # 29
# 	intersection:  56415
# 	only seg    :  88797
# 	only gt     :  90086
# 	union       :  122468
# 	IoU         :  46.07  %
#
# Test image # 30
# 	intersection:  31050
# 	only seg    :  64045
# 	only gt     :  58676
# 	union       :  91671
# 	IoU         :  33.87  %
#
# Test image # 31
# 	intersection:  41656
# 	only seg    :  72282
# 	only gt     :  75551
# 	union       :  106177
# 	IoU         :  39.23  %
#
# Test image # 32
# 	intersection:  31729
# 	only seg    :  65437
# 	only gt     :  51631
# 	union       :  85339
# 	IoU         :  37.18  %
#
# Test image # 33
# 	intersection:  53853
# 	only seg    :  78435
# 	only gt     :  75695
# 	union       :  100277
# 	IoU         :  53.7  %
#
# Test image # 34
# 	intersection:  36661
# 	only seg    :  65742
# 	only gt     :  57156
# 	union       :  86237
# 	IoU         :  42.51  %
#
# Test image # 35
# 	intersection:  36666
# 	only seg    :  66196
# 	only gt     :  78006
# 	union       :  107536
# 	IoU         :  34.1  %
#
# Test image # 36
# 	intersection:  39700
# 	only seg    :  66853
# 	only gt     :  58967
# 	union       :  86120
# 	IoU         :  46.1  %
#
# Test image # 37
# 	intersection:  52713
# 	only seg    :  82818
# 	only gt     :  64449
# 	union       :  94554
# 	IoU         :  55.75  %
#
# Test image # 38
# 	intersection:  58149
# 	only seg    :  72503
# 	only gt     :  76720
# 	union       :  91074
# 	IoU         :  63.85  %
#
# Test image # 39
# 	intersection:  58041
# 	only seg    :  110070
# 	only gt     :  68458
# 	union       :  120487
# 	IoU         :  48.17  %
#
# Test image # 40
# 	intersection:  40233
# 	only seg    :  70294
# 	only gt     :  59871
# 	union       :  89932
# 	IoU         :  44.74  %
#
# Test image # 41
# 	intersection:  40760
# 	only seg    :  76681
# 	only gt     :  58917
# 	union       :  94838
# 	IoU         :  42.98  %
#
# Test image # 42
# 	intersection:  45900
# 	only seg    :  87069
# 	only gt     :  62887
# 	union       :  104056
# 	IoU         :  44.11  %
#
# Test image # 43
# 	intersection:  37936
# 	only seg    :  75143
# 	only gt     :  53465
# 	union       :  90672
# 	IoU         :  41.84  %
#
# Test image # 44
# 	intersection:  55327
# 	only seg    :  99087
# 	only gt     :  72118
# 	union       :  115878
# 	IoU         :  47.75  %
#
# Average IoU:  44.87 %
